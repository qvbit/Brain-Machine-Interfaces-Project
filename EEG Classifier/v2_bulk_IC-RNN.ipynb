# %%
#Keras Package
import keras
from keras.models import Sequential, Model
from keras.layers import Conv1D, MaxPooling1D, Conv2D, MaxPooling2D, Flatten, LSTM, Embedding, Reshape, GRU, Input, RNN
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.normalization import BatchNormalization
from keras.optimizers import SGD, Adam
from keras.utils import np_utils, plot_model
from keras.callbacks import EarlyStopping
#Numpy
import numpy as np
#Load Data
import h5py, glob
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold, train_test_split
#Visualization
import matplotlib.pyplot as plt
#Timing
from time import time
# Out:
# D:\Utilities\Anaconda3\envs\keras\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#Import data
def import_data(filename):
    #Removes nan trial from imported data
    def remove_nan(X):
        idx = 0
        idx_nan = []
        for trial in X:
            if (np.isnan(trial).any()):
                print('Trial %d has nan' % idx)
                idx_nan.append(idx)
            idx += 1
        return np.delete(X,idx_nan,0), np.delete(y,idx_nan,0)

    #Load data
    A01T = h5py.File(filename, 'r')
    X = np.copy(A01T['image'])
    X = X[:,0:22,:] #remove EOG lines

    #769-left hand; 770-right hand; 771-both feet; 772-tongue
    y = np.copy(A01T['type'])
    y = y[0,0:X.shape[0]:1]
    y = np.asarray(y, dtype=np.int32)
    
    #Data Preprocess
    X, y = remove_nan(X) #Remove nans
    X = np.transpose(X,(0,2,1))
    X = np.expand_dims(X,3) #Expand dimension

    #Convert y to one-hot label
    encoder = LabelEncoder()
    encoder.fit(y)
    encoded_y = encoder.transform(y)
    y = np_utils.to_categorical(encoded_y)
    num_classes = y.shape[1]

    #Check whole dimensions
    print(X.shape)
    print(y.shape)
    
    return X, y, num_classes

# %%
#Load files
files = glob.glob('project_datasets/*.mat')
subjects = -1
X = {}
y = {}
for file in files:
    subjects += 1
    print(subjects)
    X[str(subjects)], y[str(subjects)], num_classes = import_data(file)
# Out:
# 0
# Trial 56 has nan
# (287, 1000, 22, 1)
# (287, 4)
# 1
# Trial 237 has nan
# Trial 284 has nan
# (286, 1000, 22, 1)
# (286, 4)
# 2
# Trial 113 has nan
# Trial 249 has nan
# (286, 1000, 22, 1)
# (286, 4)
# 3
# Trial 144 has nan
# Trial 145 has nan
# Trial 146 has nan
# Trial 179 has nan
# (284, 1000, 22, 1)
# (284, 4)
# 4
# Trial 6 has nan
# Trial 28 has nan
# Trial 57 has nan
# Trial 101 has nan
# Trial 220 has nan
# Trial 225 has nan
# (282, 1000, 22, 1)
# (282, 4)
# 5
# Trial 97 has nan
# Trial 115 has nan
# Trial 140 has nan
# (285, 1000, 22, 1)
# (285, 4)
# 6
# (288, 1000, 22, 1)
# (288, 4)
# 7
# Trial 58 has nan
# Trial 81 has nan
# Trial 124 has nan
# Trial 151 has nan
# Trial 178 has nan
# Trial 275 has nan
# (282, 1000, 22, 1)
# (282, 4)
# 8
# Trial 22 has nan
# Trial 61 has nan
# Trial 92 has nan
# Trial 93 has nan
# Trial 159 has nan
# Trial 202 has nan
# Trial 204 has nan
# Trial 218 has nan
# Trial 239 has nan
# Trial 250 has nan
# (278, 1000, 22, 1)
# (278, 4)

# %%
#Concatenate all data
t0 = time()
X_net = X[str(0)];
y_net = y[str(0)];
for i in np.arange(1,len(X)):
    X_net = np.concatenate((X_net,X[str(i)]),axis=0)
    y_net = np.concatenate((y_net,y[str(i)]),axis=0)
t1 = time()
total = t1 - t0
print("Time to concatenate = %f" % total)
print()
# Out:
# Time to concatenate = 0.838263

# %%
#Creating Validation and Testing data
X_train, X_test, y_train, y_test = train_test_split(X_net, y_net, test_size = 5/100, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 5/95, random_state=0)
print(X_net.shape)
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print()
print(y_net.shape)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (2558, 1000, 22, 1)
# (2302, 1000, 22, 1)
# (128, 1000, 22, 1)
# (128, 1000, 22, 1)
#
# (2558, 4)
# (2302, 4)
# (128, 4)
# (128, 4)

# %%
#Create Deep CNN
# Conv2D: (layer name, filter length, number of filters, stride size)
# GRU layers: (layer name, number of filters)
def create_rnn():
    activation = 'elu'
    input_shape = Input(shape = X['1'][0].shape)
    init = 'glorot_uniform'

    #Block 1
#     cnn_1 = Conv2D(25, (10,1), kernel_initializer=init)(input_shape)
#     cnn_1 = Conv2D(25, (1,22), kernel_initializer=init)(cnn_1)
#     cnn_1 = BatchNormalization()(cnn_1)
#     cnn_1 = Activation(activation)(cnn_1)
#     cnn_1 = MaxPooling2D(pool_size=(3, 1), strides=3)(cnn_1)
#     cnn_1 = Dropout(0.5)(cnn_1)
    
    #Inception 1
    tower_11 = Conv2D(50, (5,22), strides=(5,22), padding='same', kernel_initializer=init)(input_shape)
    tower_12 = Conv2D(50, (10,22), strides=(5,22), padding='same', kernel_initializer=init)(input_shape)
    tower_13 = Conv2D(50, (20,22), strides=(5,22), padding='same', kernel_initializer=init)(input_shape)
    inception_output_1 = keras.layers.concatenate([tower_11, tower_12, tower_13], axis = 3)
    inception_output_1 = BatchNormalization()(inception_output_1)
    inception_output_1 = Activation(activation)(inception_output_1)
    inception_output_1 = Dropout(0.5)(inception_output_1)
    
    #Inception 2
    tower_21 = Conv2D(50, (5,1), strides=5, padding='same', kernel_initializer=init)(inception_output_1)
    tower_22 = Conv2D(50, (10,1), strides=5, padding='same', kernel_initializer=init)(inception_output_1)
    tower_23 = Conv2D(50, (20,1), strides=5, padding='same', kernel_initializer=init)(inception_output_1)
    inception_output_2 = keras.layers.concatenate([tower_21, tower_22, tower_23], axis = 3)
    inception_output_2 = BatchNormalization()(inception_output_2)
    inception_output_2 = Activation(activation)(inception_output_2)
    inception_output_2 = Dropout(0.5)(inception_output_2)
    
    #Inception 3
    tower_31 = Conv2D(50, (5,1), strides=5, padding='same', kernel_initializer=init)(inception_output_2)
    tower_32 = Conv2D(50, (10,1), strides=5, padding='same', kernel_initializer=init)(inception_output_2)
    tower_33 = Conv2D(50, (20,1), strides=5, padding='same', kernel_initializer=init)(inception_output_2)
    inception_output_3 = keras.layers.concatenate([tower_31, tower_32, tower_33], axis = 3)
    inception_output_3 = BatchNormalization()(inception_output_3)
    inception_output_3 = Activation(activation)(inception_output_3)
    inception_output_3 = Dropout(0.5)(inception_output_3)

#     #Block 2
#     cnn_2 = Conv2D(50, (10,1), kernel_initializer=init)(cnn_1)
#     cnn_2 = BatchNormalization()(cnn_2)
#     cnn_2 = Activation(activation)(cnn_2)
#     cnn_2 = MaxPooling2D(pool_size=(3, 1), strides=3)(cnn_2)
#     cnn_2 = Dropout(0.5)(cnn_2)

#     #Block 3
#     cnn_3 = Conv2D(100, (10,1), kernel_initializer=init)(cnn_2)
#     cnn_3 = BatchNormalization()(cnn_3)
#     cnn_3 = Activation(activation)(cnn_3)
#     cnn_3 = MaxPooling2D(pool_size=(3, 1), strides=3)(cnn_3)
#     cnn_3 = Dropout(0.5)(cnn_3)

#     #Block 4
#     cnn_4 = Conv2D(200, (10,1), kernel_initializer=init)(cnn_3)
#     cnn_4 = BatchNormalization()(cnn_4)
#     cnn_4 = Activation(activation)(cnn_4)
#     cnn_4 = MaxPooling2D(pool_size=(3, 1), strides=3)(cnn_4)
#     cnn_4 = Dropout(0.5)(cnn_4)
    cnn_4 = Reshape((-1, 50*3))(inception_output_3)

    #RNN Block
#     gru_1 = GRU(200,return_sequences=True,dropout=0.1)(cnn_4)
#     gru_2 = GRU(200,return_sequences=True,dropout=0.1)(gru_1)
#     gru_output_1 = keras.layers.concatenate([gru_1, gru_2], axis = 2)

#     gru_3 = GRU(200,return_sequences=True,dropout=0.1)(gru_output_1)
#     gru_output_2 = keras.layers.concatenate([gru_1, gru_2, gru_3], axis = 2)
#     gru_4 = GRU(200,dropout=0.1)(gru_output_2)
    
    gru_1 = GRU(200,return_sequences=True,dropout=0.1)(cnn_4)
    gru_2 = GRU(200,return_sequences=True,dropout=0.1)(gru_1)
    gru_3 = GRU(200,return_sequences=True,dropout=0.1)(gru_2)
    gru_4 = GRU(200,dropout=0.1)(gru_3)
    
    out = Dense(units=4, kernel_initializer=init)(gru_4)
    out = BatchNormalization()(out)
    out = Activation('softmax')(out)
    model = Model(inputs = input_shape, outputs = out)
    return model

# %%
i = 1
model = create_rnn()
for layers in model.layers:
    print('Layer %d:' % i, layers.name)
#     print(layers.__dict__)
    if(hasattr(layers,'kernel_initializer')):
        print(layers.kernel_initializer)
    print(layers.input_shape)
    print(layers.output_shape)
    print()
    i += 1
# Out:
# Layer 1: input_22
# (None, 1000, 22, 1)
# (None, 1000, 22, 1)
#
# Layer 2: conv2d_202
# <keras.initializers.VarianceScaling object at 0x000001B5DAEC86D8>
# (None, 1000, 22, 1)
# (None, 200, 1, 50)
#
# Layer 3: conv2d_203
# <keras.initializers.VarianceScaling object at 0x000001B5EC5A1F60>
# (None, 1000, 22, 1)
# (None, 200, 1, 50)
#
# Layer 4: conv2d_204
# <keras.initializers.VarianceScaling object at 0x000001B5EC5C32B0>
# (None, 1000, 22, 1)
# (None, 200, 1, 50)
#
# Layer 5: concatenate_68
# [(None, 200, 1, 50), (None, 200, 1, 50), (None, 200, 1, 50)]
# (None, 200, 1, 150)
#
# Layer 6: batch_normalization_88
# (None, 200, 1, 150)
# (None, 200, 1, 150)
#
# Layer 7: activation_88
# (None, 200, 1, 150)
# (None, 200, 1, 150)
#
# Layer 8: dropout_37
# (None, 200, 1, 150)
# (None, 200, 1, 150)
#
# Layer 9: conv2d_205
# <keras.initializers.VarianceScaling object at 0x000001B5EC5F1B70>
# (None, 200, 1, 150)
# (None, 40, 1, 50)
#
# Layer 10: conv2d_206
# <keras.initializers.VarianceScaling object at 0x000001B5EC654E48>
# (None, 200, 1, 150)
# (None, 40, 1, 50)
#
# Layer 11: conv2d_207
# <keras.initializers.VarianceScaling object at 0x000001B5EC7DF7B8>
# (None, 200, 1, 150)
# (None, 40, 1, 50)
#
# Layer 12: concatenate_69
# [(None, 40, 1, 50), (None, 40, 1, 50), (None, 40, 1, 50)]
# (None, 40, 1, 150)
#
# Layer 13: batch_normalization_89
# (None, 40, 1, 150)
# (None, 40, 1, 150)
#
# Layer 14: activation_89
# (None, 40, 1, 150)
# (None, 40, 1, 150)
#
# Layer 15: dropout_38
# (None, 40, 1, 150)
# (None, 40, 1, 150)
#
# Layer 16: conv2d_208
# <keras.initializers.VarianceScaling object at 0x000001B5EC80ED30>
# (None, 40, 1, 150)
# (None, 8, 1, 50)
#
# Layer 17: conv2d_209
# <keras.initializers.VarianceScaling object at 0x000001B5EC94DDA0>
# (None, 40, 1, 150)
# (None, 8, 1, 50)
#
# Layer 18: conv2d_210
# <keras.initializers.VarianceScaling object at 0x000001B5EC995400>
# (None, 40, 1, 150)
# (None, 8, 1, 50)
#
# Layer 19: concatenate_70
# [(None, 8, 1, 50), (None, 8, 1, 50), (None, 8, 1, 50)]
# (None, 8, 1, 150)
#
# Layer 20: batch_normalization_90
# (None, 8, 1, 150)
# (None, 8, 1, 150)
#
# Layer 21: activation_90
# (None, 8, 1, 150)
# (None, 8, 1, 150)
#
# Layer 22: dropout_39
# (None, 8, 1, 150)
# (None, 8, 1, 150)
#
# Layer 23: reshape_21
# (None, 8, 1, 150)
# (None, 8, 150)
#
# Layer 24: gru_74
# <keras.initializers.VarianceScaling object at 0x000001B5ECA2F710>
# (None, 8, 150)
# (None, 8, 200)
#
# Layer 25: gru_75
# <keras.initializers.VarianceScaling object at 0x000001B5ECB814E0>
# (None, 8, 200)
# (None, 8, 200)
#
# Layer 26: gru_76
# <keras.initializers.VarianceScaling object at 0x000001B5ECB8AB38>
# (None, 8, 200)
# (None, 8, 200)
#
# Layer 27: gru_77
# <keras.initializers.VarianceScaling object at 0x000001B5ECD8B128>
# (None, 8, 200)
# (None, 200)
#
# Layer 28: dense_19
# <keras.initializers.VarianceScaling object at 0x000001B5ED1AA0B8>
# (None, 200)
# (None, 4)
#
# Layer 29: batch_normalization_91
# (None, 4)
# (None, 4)
#
# Layer 30: activation_91
# (None, 4)
# (None, 4)

# %%
#Training
batch_size = 16
epochs = 60
opt = keras.optimizers.adam(lr=0.001)
results = []

model = create_rnn()
model.compile(loss='categorical_crossentropy',
             optimizer=opt,
             metrics=['accuracy'])
result = model.fit(X_train, y_train,
                   batch_size=batch_size,
                   validation_data=(X_val, y_val),
                   epochs=epochs)
results.append(result.history['val_acc'])

plt.plot(result.history['acc'])
plt.plot(result.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# Train on 2302 samples, validate on 128 samples
# Epoch 1/60
# 2302/2302 [==============================] - 16s 7ms/step - loss: 1.4234 - acc: 0.2537 - val_loss: 1.3690 - val_acc: 0.3281
# Epoch 2/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.3784 - acc: 0.2880 - val_loss: 1.3647 - val_acc: 0.3203
# Epoch 3/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.3711 - acc: 0.3084 - val_loss: 1.3807 - val_acc: 0.2812
# Epoch 4/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.3460 - acc: 0.3501 - val_loss: 1.3607 - val_acc: 0.2969
# Epoch 5/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.3424 - acc: 0.3501 - val_loss: 1.2952 - val_acc: 0.3594
# Epoch 6/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.2999 - acc: 0.4062 - val_loss: 1.3268 - val_acc: 0.3984
# Epoch 7/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.3024 - acc: 0.4092 - val_loss: 1.2669 - val_acc: 0.4297
# Epoch 8/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.2792 - acc: 0.4088 - val_loss: 1.2266 - val_acc: 0.4453
# Epoch 9/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.2450 - acc: 0.4405 - val_loss: 1.4140 - val_acc: 0.3125
# Epoch 10/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.1979 - acc: 0.4718 - val_loss: 1.1677 - val_acc: 0.4688
# Epoch 11/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.1639 - acc: 0.4857 - val_loss: 1.1398 - val_acc: 0.4375
# Epoch 12/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.1413 - acc: 0.5078 - val_loss: 1.1490 - val_acc: 0.5234
# Epoch 13/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.1364 - acc: 0.5130 - val_loss: 1.1672 - val_acc: 0.4766
# Epoch 14/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.1182 - acc: 0.5165 - val_loss: 1.1482 - val_acc: 0.4297
# Epoch 15/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.0818 - acc: 0.5348 - val_loss: 1.0504 - val_acc: 0.5938
# Epoch 16/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.0496 - acc: 0.5647 - val_loss: 1.1334 - val_acc: 0.4922
# Epoch 17/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.0461 - acc: 0.5569 - val_loss: 1.2695 - val_acc: 0.4062
# Epoch 18/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.0510 - acc: 0.5660 - val_loss: 1.0583 - val_acc: 0.5391
# Epoch 19/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 1.0165 - acc: 0.5804 - val_loss: 1.1068 - val_acc: 0.5234
# Epoch 20/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.9859 - acc: 0.5943 - val_loss: 1.1536 - val_acc: 0.5234
# Epoch 21/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.9742 - acc: 0.6047 - val_loss: 1.1346 - val_acc: 0.5000
# Epoch 22/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.9310 - acc: 0.6281 - val_loss: 1.1978 - val_acc: 0.4844
# Epoch 23/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.9579 - acc: 0.6103 - val_loss: 1.1794 - val_acc: 0.5156
# Epoch 24/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.9233 - acc: 0.6273 - val_loss: 1.1033 - val_acc: 0.5703
# Epoch 25/60
# 2302/2302 [==============================] - ETA: 0s - loss: 0.9149 - acc: 0.640 - 6s 3ms/step - loss: 0.9157 - acc: 0.6399 - val_loss: 1.1003 - val_acc: 0.5234
# Epoch 26/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.8734 - acc: 0.6620 - val_loss: 1.6121 - val_acc: 0.4219
# Epoch 27/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.8645 - acc: 0.6642 - val_loss: 1.1196 - val_acc: 0.5938
# Epoch 28/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.8334 - acc: 0.6690 - val_loss: 1.1621 - val_acc: 0.5469
# Epoch 29/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.8017 - acc: 0.6929 - val_loss: 1.1828 - val_acc: 0.5703
# Epoch 30/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.8077 - acc: 0.6898 - val_loss: 1.1621 - val_acc: 0.5469
# Epoch 31/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.7741 - acc: 0.6985 - val_loss: 1.2277 - val_acc: 0.5156
# Epoch 32/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.7325 - acc: 0.7255 - val_loss: 1.2206 - val_acc: 0.5078
# Epoch 33/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.7074 - acc: 0.7359 - val_loss: 1.2345 - val_acc: 0.5078
# Epoch 34/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.7164 - acc: 0.7411 - val_loss: 1.2374 - val_acc: 0.5391
# Epoch 35/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.6911 - acc: 0.7489 - val_loss: 1.2494 - val_acc: 0.5156
# Epoch 36/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.7030 - acc: 0.7359 - val_loss: 1.2026 - val_acc: 0.5391
# Epoch 37/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.6546 - acc: 0.7606 - val_loss: 1.1851 - val_acc: 0.5781
# Epoch 38/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.6602 - acc: 0.7541 - val_loss: 1.1502 - val_acc: 0.5703
# Epoch 39/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.6003 - acc: 0.7876 - val_loss: 1.1209 - val_acc: 0.6094
# Epoch 40/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5934 - acc: 0.7767 - val_loss: 1.1434 - val_acc: 0.5703
# Epoch 41/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.6048 - acc: 0.7745 - val_loss: 1.1886 - val_acc: 0.6016
# Epoch 42/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5919 - acc: 0.7815 - val_loss: 1.2435 - val_acc: 0.5625
# Epoch 43/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5701 - acc: 0.7963 - val_loss: 1.3431 - val_acc: 0.5312
# Epoch 44/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5555 - acc: 0.8080 - val_loss: 1.1685 - val_acc: 0.5781
# Epoch 45/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5244 - acc: 0.8158 - val_loss: 1.2574 - val_acc: 0.5547
# Epoch 46/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5472 - acc: 0.8106 - val_loss: 1.2163 - val_acc: 0.5469
# Epoch 47/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4980 - acc: 0.8223 - val_loss: 1.3218 - val_acc: 0.5547
# Epoch 48/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5006 - acc: 0.8262 - val_loss: 1.2317 - val_acc: 0.5938
# Epoch 49/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5163 - acc: 0.8189 - val_loss: 1.2283 - val_acc: 0.5859
# Epoch 50/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.5039 - acc: 0.8232 - val_loss: 1.3055 - val_acc: 0.5391
# Epoch 51/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4814 - acc: 0.8315 - val_loss: 1.3414 - val_acc: 0.5781
# Epoch 52/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4811 - acc: 0.8319 - val_loss: 1.3851 - val_acc: 0.5781
# Epoch 53/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4750 - acc: 0.8275 - val_loss: 1.1945 - val_acc: 0.6094
# Epoch 54/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4677 - acc: 0.8362 - val_loss: 1.1699 - val_acc: 0.6250
# Epoch 55/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4237 - acc: 0.8488 - val_loss: 1.2558 - val_acc: 0.5859
# Epoch 56/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4181 - acc: 0.8675 - val_loss: 1.3649 - val_acc: 0.5703
# Epoch 57/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4427 - acc: 0.8445 - val_loss: 1.3411 - val_acc: 0.5781
# Epoch 58/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4441 - acc: 0.8458 - val_loss: 1.2913 - val_acc: 0.5859
# Epoch 59/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.4308 - acc: 0.8454 - val_loss: 1.3292 - val_acc: 0.5781
# Epoch 60/60
# 2302/2302 [==============================] - 6s 3ms/step - loss: 0.3958 - acc: 0.8623 - val_loss: 1.3491 - val_acc: 0.6094

# %%
# Testing Accuracy
test_results = model.predict(x=X_test, batch_size=batch_size)
categ_results = np.argmax(test_results,axis=1)
categ_test = np.argmax(y_test,axis=1)
test_acc = np.sum(categ_results==categ_test)/len(categ_results)
print('Training Accuracy: %.3f' % result.history['acc'][-1])
print('Validation Accuracy: %.3f' % result.history['val_acc'][-1])
print('Testing Accuracy: %.3f' % test_acc)
# Out:
# Training Accuracy: 0.862
# Validation Accuracy: 0.609
# Testing Accuracy: 0.539
